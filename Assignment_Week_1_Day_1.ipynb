# %% [markdown]
# <a href="https://colab.research.google.com/github/prav87654/Airbnb-EDA/blob/main/Assignment_Week_1_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 1. What is the value of the function (x − 1) (x − 2)^2 at its maxima?
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![Day 1 1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Compute the Jacobian of the following transformation.
#
#  ![image.png](data:image/png;base64,...)
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![Day 1-2.jpeg](data:image/jpeg;base64,...)Upload your answer here.

# %% [markdown]
# ## 3. Given v = i - 2j + 2k and u = 4i - 3k, Find
# ## --the component of v in the direction of u,
#
# ## --the projection of v in the direction of u,
#
# ## --the resolution of v into components parallel and perpendicular to u.
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![Day1 --3.jpeg](data:image/jpeg;base64,...)Upload your answer here.

# %% [markdown]
# ## 4. Find a vector that is orthogonal to the plane containing the points P=(3,0,1), Q=(4,−2,1) and R=(5,3,−1).
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![Day ! 4.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 5. How do you choose a machine learning algorithm for a problem statement?
# ## Explain Briefly.

# %% [markdown]
# It is based on many criteria such as:
# 1. Understanding our project goal
# 2. The data structure and its complexity
# 3.Visualization of Data
# 4.By applying Pairplot to choose which algorithm will have desired result
# 5.Size of our Dataset

# %% [markdown]
# ## 6. What is Semi- Supervised Learning and why is it so important?

# %% [markdown]
# It is an approach for Machine Learning where we train our model with the combination of some labeled data and a large amount of unlabeled data .sometimes we cannot choose between either an unsupervised or a supervised ML algorithm. There are cases where combining the two algorithms can bring you more benefits even with regard to the growing complexity of your ML model. That’s because of the core features of each type of algorithm: unsupervised learning brings in simplicity and efficiency while supervised learning is all about flexibility and comprehensive goals.

# %% [markdown]
# ## 7. Why we can’t do a classification problem using Regression?

# %% [markdown]
# The first one is that Linear Regression deals with continuous values whereas classification problems mandate discrete values.Linear Regression is highly impacted by outliers. Hence we cannot use it to solve a classification problems.
#
# We need an algorithm that absorbs the effects of outliers without impacting the final output. Logistic regression does that by using something called a Sigmoid function. And that’s the reason why Logistic regression is our go-to algorithm when it comes to solving classification problems.

# %% [markdown]
# ## 8. How do you treat heteroscedasticity in regression? What causes Heteroscedasticity and how to fix it?

# %% [markdown]
# Heteroscedasticity it refers to data with unequal variability (scatter) across a set of predictor variables.It is mainly due to the presence of outlier in the data. Outlier in Heteroscedasticity means that the observations that are either small or large with respect to the other observations are present in the sample. Heteroscedasticity is also caused due to omission of variables from the model.
#
# Through transforming the dependent variable, redefining the dependent variable, or using weighted regression, the problem of heteroscedasticity can often be eliminated.
